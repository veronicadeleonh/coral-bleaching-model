# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

import scipy.stats as st
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from scipy.stats import ttest_ind


from sklearn.model_selection import train_test_split

from sklearn.cluster import KMeans  
import xgboost as xgb

# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error

from sklearn.model_selection import cross_val_score

# %%
coral = pd.read_csv("data/coral_clean.csv")

pd.set_option('display.max_columns', None)

display(coral)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 coral = pd.read_csv("data/coral_clean.csv")
#       3 pd.set_option('display.max_columns', None)
#       5 display(coral)
#
# File ~/Desktop/Bootcamp/finalproject/corals/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/Bootcamp/finalproject/corals/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/Bootcamp/finalproject/corals/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/Bootcamp/finalproject/corals/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/Bootcamp/finalproject/corals/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/coral_clean.csv'

# %%
# LOWERCASE ALL DF

coral = coral.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_86647/2964530727.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   coral = coral.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
# DATE

coral['date'] = pd.to_datetime(coral['date'])
 
coral['month'] = coral['date'].dt.month  
coral['year'] = coral['date'].dt.year

# %%
coral.groupby('month')['percent_bleaching'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
coral.groupby('year')['windspeed'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
coral.groupby(['year', 'ocean'])["sst"].mean()
# Out:
# year  ocean
# 1980  pacific     297.143214
# 1983  atlantic    302.380000
#       indian      301.890000
#       pacific     302.545833
# 1986  indian      301.580000
#                      ...
# 2019  pacific     301.993598
#       red sea     299.876579
# 2020  indian      301.374925
#       pacific     301.374518
#       red sea     301.376375
# Name: sst, Length: 131, dtype: float64

# %%
# OCEAN 

coral["ocean"].value_counts()
# Out:
# ocean
# atlantic        11199
# pacific          9809
# indian           1461
# red sea           533
# arabian gulf      201
# Name: count, dtype: int64

# %%
# H0: mu pb arabian gulf = mu pb atlantinc = mu pb indian = mu pb pacific = mu pb read sea
# H1: mu pb arabian gulf != mu pb atlantinc != mu pb indian != mu pb pacific != mu pb read sea

#alpha = 0.05

tukey_ocean = pairwise_tukeyhsd(coral['percent_bleaching'], coral['ocean'])

print(tukey_ocean)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1     group2  meandiff p-adj   lower    upper   reject
# --------------------------------------------------------------
# arabian gulf atlantic   4.7152 0.0282   0.3224   9.1079   True
# arabian gulf   indian   7.6558 0.0001   3.0121  12.2995   True
# arabian gulf  pacific  -2.2328 0.6374   -6.631   2.1654  False
# arabian gulf  red sea -10.4978    0.0  -15.607  -5.3885   True
#     atlantic   indian   2.9406    0.0   1.2236   4.6577   True
#     atlantic  pacific   -6.948    0.0  -7.8016  -6.0944   True
#     atlantic  red sea -15.2129    0.0 -17.9495 -12.4764   True
#       indian  pacific  -9.8886    0.0 -11.6196  -8.1576   True
#       indian  red sea -18.1536    0.0 -21.2771   -15.03   True
#      pacific  red sea   -8.265    0.0 -11.0103  -5.5196   True
# --------------------------------------------------------------

# %%
coral['ocean'] = coral['ocean'].replace({'arabian gulf': 'pacific/arabian gulf', 'pacific': 'pacific/arabian gulf'})

# %%
# REALM

coral["realm"].value_counts()
# Out:
# realm
# tropical atlantic              11185
# central indo-pacific            8310
# western indo-pacific            2040
# eastern indo-pacific             946
# temperate northern pacific       357
# temperate australasia            273
# tropical eastern pacific          78
# temperate northern atlantic       14
# Name: count, dtype: int64

# %%
#alpha = 0.05

tukey_realm = pairwise_tukeyhsd(coral['percent_bleaching'], coral['realm'])

print(tukey_realm)
# Out:
#                       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================================================
#            group1                      group2           meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------------------------------------
#        central indo-pacific        eastern indo-pacific  -0.8895 0.9472  -3.2473   1.4683  False
#        central indo-pacific       temperate australasia  -4.0384 0.0733  -8.2648   0.1881  False
#        central indo-pacific temperate northern atlantic   8.7704 0.8355  -9.6094  27.1502  False
#        central indo-pacific  temperate northern pacific  -1.4673 0.9329  -5.1812   2.2467  False
#        central indo-pacific           tropical atlantic   6.8473    0.0   5.8522   7.8425   True
#        central indo-pacific    tropical eastern pacific  33.7602    0.0  25.9435  41.5768   True
#        central indo-pacific        western indo-pacific   4.4833    0.0   2.7855   6.1811   True
#        eastern indo-pacific       temperate australasia  -3.1489 0.4669  -7.8697   1.5719  False
#        eastern indo-pacific temperate northern atlantic   9.6599 0.7609  -8.8398  28.1597  False
#        eastern indo-pacific  temperate northern pacific  -0.5778 0.9999  -4.8458   3.6903  False
#        eastern indo-pacific           tropical atlantic   7.7368    0.0   5.4102  10.0634   True
#        eastern indo-pacific    tropical eastern pacific  34.6496    0.0   26.555  42.7443   True
#        eastern indo-pacific        western indo-pacific   5.3728    0.0   2.6699   8.0757   True
#       temperate australasia temperate northern atlantic  12.8088 0.4399  -6.0206  31.6381  False
#       temperate australasia  temperate northern pacific   2.5711 0.8527  -2.9534   8.0956  False
#       temperate australasia           tropical atlantic  10.8857    0.0   6.6765  15.0948   True
#       temperate australasia    tropical eastern pacific  37.7985    0.0  28.9766  46.6205   True
#       temperate australasia        western indo-pacific   8.5217    0.0   4.0934  12.9499   True
# temperate northern atlantic  temperate northern pacific -10.2377 0.7148 -28.9587   8.4833  False
# temperate northern atlantic           tropical atlantic  -1.9231    1.0  -20.299  16.4528  False
# temperate northern atlantic    tropical eastern pacific  24.9897 0.0037   5.0453  44.9342   True
# temperate northern atlantic        western indo-pacific  -4.2871 0.9969 -22.7144  14.1402  False
#  temperate northern pacific           tropical atlantic   8.3146    0.0   4.6203  12.0088   True
#  temperate northern pacific    tropical eastern pacific  35.2274    0.0  26.6392  43.8156   True
#  temperate northern pacific        western indo-pacific   5.9506 0.0001   2.0085   9.8926   True
#           tropical atlantic    tropical eastern pacific  26.9128    0.0  19.1055  34.7202   True
#           tropical atlantic        western indo-pacific   -2.364 0.0004  -4.0183  -0.7098   True
#    tropical eastern pacific        western indo-pacific -29.2769    0.0 -37.2044 -21.3493   True
# ------------------------------------------------------------------------------------------------

# %%
group_mapping = {
    'central indo-pacific': 'central & eastern indo-pacific',
    'eastern indo-pacific': 'central & eastern indo-pacific',
    'temperate australasia': 'central & temperate australasia',
    'temperate northern atlantic': 'temperate northern atlantic & tropical atlantic',
    'temperate northern pacific': 'temperate northern pacific & temperate australasia',
    'temperate northern atlantic': 'temperate northern atlantic & tropical atlantic',
}

coral['realm'] = coral['realm'].replace(group_mapping)

# %%
# ECOREGION

coral['ecoregion'].value_counts()
# Out:
# ecoregion
# bahamas and florida keys                      3802
# belize and west caribbean                     3290
# hispaniola puerto rico and lesser antilles    1902
# sunda shelf south-east asia                   1236
# sulu sea                                      1007
#                                               ...
# central vietnam                                  1
# isla de malpelo colombia                         1
# rowley shoals west australia                     1
# arnhem land north australia                      1
# houtman abrolhos islands west australia          1
# Name: count, Length: 113, dtype: int64

# %%
coral = coral.drop("ecoregion", axis=1)

# %%
# EXPOSURE 

coral["exposure"].value_counts()
# Out:
# exposure
# sheltered    11758
# exposed       9210
# sometimes     2235
# Name: count, dtype: int64

# %%
# H0: mu exposure exposed = mu exposure sheltered = mu exposure sometimes
# H1: mu exposure exposed != mu exposure sheltered != mu exposure sometimes

#alpha = 0.05

exposure_exposed = coral[coral["exposure"]=="exposed"]["percent_bleaching"]
exposure_sheltered = coral[coral["exposure"]=="sheltered"]["percent_bleaching"]
exposure_sometimes = coral[coral["exposure"]=="sometimes"]["percent_bleaching"]

st.f_oneway(exposure_exposed, exposure_sheltered, exposure_sometimes)
# Out:
# F_onewayResult(statistic=np.float64(246.95574894285156), pvalue=np.float64(7.484904893758175e-107))

# %%
tukey_exposure = pairwise_tukeyhsd(endog=coral["percent_bleaching"],  
                           groups=coral["exposure"],  
                           alpha=0.05)
print(tukey_exposure)
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#   group1    group2  meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------
#   exposed sheltered  -4.8042   0.0 -5.5462 -4.0623   True
#   exposed sometimes    5.524   0.0  4.2667  6.7813   True
# sheltered sometimes  10.3283   0.0  9.0979 11.5586   True
# ---------------------------------------------------------

# %%
# --> all go in

# %%
# BLEACHING LEVEL

coral['bleaching_level'].value_counts()
# Out:
# bleaching_level
# colony        11950
# population    11253
# Name: count, dtype: int64

# %%
#alpha = 0.05

bleaching_level_colony = coral[coral["bleaching_level"]=="colony"]["percent_bleaching"]
bleaching_level_population = coral[coral["bleaching_level"]=="population"]["percent_bleaching"]

st.f_oneway(bleaching_level_colony, bleaching_level_population)
# Out:
# F_onewayResult(statistic=np.float64(5681.960684833286), pvalue=np.float64(0.0))

# %%
tukey_bleaching_level = pairwise_tukeyhsd(endog=coral["percent_bleaching"],  
                           groups=coral["bleaching_level"],  
                           alpha=0.05)
print(tukey_bleaching_level)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1   group2   meandiff p-adj  lower   upper  reject
# -------------------------------------------------------
# colony population -20.4015   0.0 -20.932 -19.871   True
# -------------------------------------------------------

# %%
coral_population = coral[coral['bleaching_level'] == "population"]
coral_colony = coral[coral['bleaching_level'] == "colony"]

# display(coral_population)
# display(coral_colony)

# %%
coral.groupby('bleaching_level')[['sst', 'sst_maximum', 'ssta', 'ssta_maximum', 'tsa']].mean()
# Out:
#                         sst  sst_maximum      ssta  ssta_maximum       tsa
# bleaching_level
# colony           301.619357   305.064858  0.333198      3.392758 -0.737765
# population       301.247226   305.169963  0.251228      3.494187 -1.078987

# %%
t_stat, p_value = ttest_ind(coral_colony["tsa"], coral_population["tsa"], equal_var=False)
print(f't_stat: {t_stat}, p_value: {p_value}')
# Out:
# t_stat: 15.663163193097056, p_value: 5.173978362102082e-55

# %%
coral.columns
# Out:
# Index(['date', 'latitude', 'longitude', 'ocean', 'realm', 'distance_to_shore',
#        'exposure', 'depth_m', 'turbidity', 'bleaching_level',
#        'percent_bleaching', 'cyclone_frequency', 'windspeed', 'sst',
#        'sst_maximum', 'ssta', 'ssta_maximum', 'ssta_frequency', 'tsa',
#        'ssta_dhw', 'tsa_maximum', 'tsa_frequency', 'tsa_dhw', 'month', 'year'],
#       dtype='object')

# %%
# REMOVING NOISE

coral = coral[['latitude', 'longitude', 'ocean', 'realm', 'distance_to_shore',
       'exposure', 'depth_m', 'turbidity', 'bleaching_level',
       'percent_bleaching', 'cyclone_frequency', 'windspeed', 'sst',
       'sst_maximum', 'ssta', 'ssta_maximum', 'ssta_frequency', 'tsa',
       'ssta_dhw', 'tsa_maximum', 'tsa_frequency', 'tsa_dhw']]

# %%
coral
# Out:
#        latitude  longitude                 ocean  \
# 0       23.1630   -82.5260              atlantic
# 1      -17.5750  -149.7833  pacific/arabian gulf
# 2       18.3690   -64.5640              atlantic
# 3       17.7600   -64.5680              atlantic
# 4       17.7690   -64.5830              atlantic
# ...         ...        ...                   ...
# 23198   10.1167    99.8444  pacific/arabian gulf
# 23199   18.3350   -64.8486              atlantic
# 23200  -13.5002    47.8825                indian
# 23201   24.5019   -81.6328              atlantic
# 23202   24.9542   -80.5458              atlantic
#
#                                 realm  distance_to_shore   exposure  depth_m  \
# 0                   tropical atlantic            8519.23    exposed    10.00
# 1      central & eastern indo-pacific            1431.62    exposed    14.00
# 2                   tropical atlantic             182.33    exposed     7.00
# 3                   tropical atlantic             313.13    exposed     9.02
# 4                   tropical atlantic             792.00    exposed    12.50
# ...                               ...                ...        ...      ...
# 23198  central & eastern indo-pacific              73.88    exposed     5.00
# 23199               tropical atlantic              49.16  sheltered     3.00
# 23200            western indo-pacific            8768.03  sometimes    14.00
# 23201               tropical atlantic            8170.00    exposed     4.00
# 23202               tropical atlantic            1863.00  sheltered     4.00
#
#        turbidity bleaching_level  percent_bleaching  cyclone_frequency  \
# 0         0.0287          colony               50.2              49.90
# 1         0.0262          colony               50.7              51.20
# 2         0.0429          colony               50.9              61.52
# 3         0.0424          colony               50.9              65.39
# 4         0.0424          colony               50.9              65.39
# ...          ...             ...                ...                ...
# 23198     0.0565      population              100.0              50.27
# 23199     0.0586      population              100.0              85.57
# 23200     0.0628          colony              100.0              35.71
# 23201     0.1203          colony              100.0              58.42
# 23202     0.1703          colony              100.0              62.54
#
#        windspeed     sst  sst_maximum  ssta  ssta_maximum  ssta_frequency  \
# 0            8.0  302.05       304.69 -0.46          2.24             0.0
# 1            2.0  303.30       305.01  1.29          3.10             0.5
# 2            8.0  299.18       304.14  0.04          2.83            16.0
# 3            3.0  299.61       304.07 -0.07          2.47            22.0
# 4            3.0  299.70       303.76  0.00          2.30            16.0
# ...          ...     ...          ...   ...           ...             ...
# 23198        2.0  304.79       306.89  1.40          3.74             2.0
# 23199        8.0  302.11       303.67  0.32          2.34            12.0
# 23200        5.0  303.45       305.32  0.63          2.50             9.0
# 23201        5.0  303.76       306.04  3.91          6.20            25.0
# 23202        2.0  302.70       306.82  1.59          4.11            22.0
#
#         tsa  ssta_dhw  tsa_maximum  tsa_frequency  tsa_dhw
# 0     -0.80      0.00         1.83           0.00     0.00
# 1      1.29      0.26         3.00           0.25     0.26
# 2     -2.64      0.00         2.31           7.00     0.00
# 3     -2.27      0.00         2.19           3.00     0.00
# 4     -2.19      0.00         1.87           3.00     0.00
# ...     ...       ...          ...            ...      ...
# 23198  1.26      1.37         3.35           1.00     1.33
# 23199  0.21     10.14         1.76           5.00     6.22
# 23200  0.59      5.81         2.46           4.00     4.44
# 23201  3.91     51.11         6.19          25.00    50.63
# 23202 -0.57     10.59         3.54           5.00     7.16
#
# [23203 rows x 22 columns]

# %%
# CREATING DUMMIES 

coral = pd.get_dummies(coral, columns=["ocean", "realm", "exposure", "bleaching_level"], drop_first=True)

# %%
# INTERACTIONS

# coral["ssta_depth_interaction"] = coral["ssta"] * coral["depth_m"]
# coral["sst_tsa_interaction"] = coral["ssta"] * coral["tsa"]

# coral["sst_depth_interaction"] = coral["sst"] * coral["depth_m"]
# coral["sst_exposure_sheltered"] = coral["sst"] * coral["exposure_sheltered"]

# coral["sst_max_depth_interaction"] = coral["sst_max"] * coral["depth_m"]
# coral["sst_max_exposure_interaction"] = coral["sst_max"] * coral["exposure_sheltered"]
# coral["sst_max_cyclone_interaction"] = coral["sst_max"] * coral["cyclone_frequency"]

# coral["ssta_sst_interaction"] = coral["ssta"] * coral["sst"]

# %%
coral[['depth_m', 'distance_to_shore']]
# Out:
#        depth_m  distance_to_shore
# 0        10.00            8519.23
# 1        14.00            1431.62
# 2         7.00             182.33
# 3         9.02             313.13
# 4        12.50             792.00
# ...        ...                ...
# 23198     5.00              73.88
# 23199     3.00              49.16
# 23200    14.00            8768.03
# 23201     4.00            8170.00
# 23202     4.00            1863.00
#
# [23203 rows x 2 columns]

# %%
# CHECKING FOR OUTLIERS

numerical_columns = coral.select_dtypes(include=['float64', 'int64'])

Q1 = numerical_columns.quantile(0.25)
Q3 = numerical_columns.quantile(0.75)
IQR = Q3 - Q1

non_outliers = ~((numerical_columns < (Q1 - 1.5 * IQR)) | (numerical_columns > (Q3 + 1.5 * IQR))).any(axis=1)

coral = coral[non_outliers]

coral
# Out:
#        latitude  longitude  distance_to_shore  depth_m  turbidity  \
# 1849    24.4571   124.0986             434.38      5.0     0.0422
# 1850    24.7998   125.1786             842.80     10.0     0.0440
# 1851    26.2476   127.6682              75.90      0.5     0.0420
# 1852    26.2752   127.7141              49.66     10.0     0.0438
# 1853    26.4435   127.7727              12.45      1.5     0.0341
# ...         ...        ...                ...      ...        ...
# 22462   18.7083   -87.7056             700.14     10.0     0.0279
# 22463   18.7083   -87.7056             700.14     10.1     0.0279
# 22464   18.7083   -87.7056             700.14     10.3     0.0279
# 22465   24.9992   -80.4670            3316.00      4.3     0.1405
# 22469  -17.9786   179.2251            2343.09      7.0     0.0428
#
#        percent_bleaching  cyclone_frequency  windspeed     sst  sst_maximum  \
# 1849                0.00              50.23        6.0  300.94       305.10
# 1850                0.00              68.54        5.0  299.15       304.35
# 1851                0.00              67.60        4.0  301.26       304.27
# 1852                0.00              65.56        7.0  302.52       304.28
# 1853                0.00              64.30        5.0  301.95       304.95
# ...                  ...                ...        ...     ...          ...
# 22462              32.52              49.10        7.0  301.24       304.60
# 22463              32.52              49.10        7.0  301.24       304.60
# 22464              32.52              49.10        7.0  301.24       304.60
# 22465              32.55              62.54        4.0  303.17       305.61
# 22469              33.00              42.61        4.0  301.67       304.35
#
#        ssta  ssta_maximum  ssta_frequency   tsa  ssta_dhw  tsa_maximum  \
# 1849  -0.50          3.05            4.00 -1.26      0.00         2.89
# 1850  -0.80          3.38            8.00 -2.82      4.15         2.38
# 1851  -0.28          2.78            4.00 -0.34      1.35         2.66
# 1852   1.34          2.92            3.67  0.95      0.34         2.70
# 1853   0.25          3.73            4.00  0.20      0.00         3.19
# ...     ...           ...             ...   ...       ...          ...
# 22462 -0.20          3.48            2.00 -1.02      0.00         2.32
# 22463 -0.20          3.48            2.00 -1.02      0.00         2.32
# 22464 -0.20          3.48            2.00 -1.02      0.00         2.32
# 22465  1.24          3.61           15.00 -0.04      4.54         2.39
# 22469  0.56          3.99           17.00 -0.05      3.68         2.62
#
#        tsa_frequency  tsa_dhw  ocean_indian  ocean_pacific/arabian gulf  \
# 1849            0.00     0.00         False                        True
# 1850            1.00     0.00         False                        True
# 1851            0.00     0.00         False                        True
# 1852            0.33     0.00         False                        True
# 1853            0.00     0.00         False                        True
# ...              ...      ...           ...                         ...
# 22462           2.00     0.00         False                       False
# 22463           2.00     0.00         False                       False
# 22464           2.00     0.00         False                       False
# 22465           2.00     2.84         False                       False
# 22469           3.00     2.51         False                        True
#
#        ocean_red sea  realm_central & temperate australasia  \
# 1849           False                                  False
# 1850           False                                  False
# 1851           False                                  False
# 1852           False                                  False
# 1853           False                                  False
# ...              ...                                    ...
# 22462          False                                  False
# 22463          False                                  False
# 22464          False                                  False
# 22465          False                                  False
# 22469          False                                  False
#
#        realm_temperate northern atlantic & tropical atlantic  \
# 1849                                               False
# 1850                                               False
# 1851                                               False
# 1852                                               False
# 1853                                               False
# ...                                                  ...
# 22462                                              False
# 22463                                              False
# 22464                                              False
# 22465                                              False
# 22469                                              False
#
#        realm_temperate northern pacific & temperate australasia  \
# 1849                                               False
# 1850                                               False
# 1851                                               False
# 1852                                               False
# 1853                                               False
# ...                                                  ...
# 22462                                              False
# 22463                                              False
# 22464                                              False
# 22465                                              False
# 22469                                              False
#
#        realm_tropical atlantic  realm_tropical eastern pacific  \
# 1849                     False                           False
# 1850                     False                           False
# 1851                     False                           False
# 1852                     False                           False
# 1853                     False                           False
# ...                        ...                             ...
# 22462                     True                           False
# 22463                     True                           False
# 22464                     True                           False
# 22465                     True                           False
# 22469                    False                           False
#
#        realm_western indo-pacific  exposure_sheltered  exposure_sometimes  \
# 1849                        False               False               False
# 1850                        False               False               False
# 1851                        False                True               False
# 1852                        False               False               False
# 1853                        False               False               False
# ...                           ...                 ...                 ...
# 22462                       False               False                True
# 22463                       False               False                True
# 22464                       False               False                True
# 22465                       False                True               False
# 22469                       False                True               False
#
#        bleaching_level_population
# 1849                        False
# 1850                        False
# 1851                        False
# 1852                        False
# 1853                        False
# ...                           ...
# 22462                       False
# 22463                       False
# 22464                       False
# 22465                       False
# 22469                        True
#
# [11411 rows x 30 columns]

# %%
# # CLUSTERS

# geo_env_features = coral[['depth_m', 'distance_to_shore']]
# kmeans_env = KMeans(n_clusters=4, random_state=42)
# coral['geo_env_cluster'] = kmeans_env.fit_predict(geo_env_features)

# coral

# %%
# FEATURE SELECTION

features = coral.drop(['percent_bleaching'], axis=1)
target = coral["percent_bleaching"]

# %%
# TRAINING MODEL

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20)

# %%
# NORMALIZING VALUES

normalizer = MinMaxScaler()

normalizer.fit(X_train)
X_train_norm = normalizer.transform(X_train)
X_test_norm = normalizer.transform(X_test)

# %%
# XGBOOST

import xgboost

xbg_r = xgboost.XGBRegressor(n_estimators=100, max_depth=4)

# %%
xbg_r.fit(X_train_norm, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
pred = xbg_r.predict(X_test_norm)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", root_mean_squared_error(pred, y_test))
print("R2 score", xbg_r.score(X_test_norm, y_test))
# Out:
# MAE 2.9572770571533757
# RMSE 5.196601721281355
# R2 score 0.48661414519885093

# %%
# CHECK OVERFIT 

pred = xbg_r.predict(X_train_norm)

print("MAE", mean_absolute_error(pred, y_train))
print("RMSE", root_mean_squared_error(pred, y_train))
print("R2 score", xbg_r.score(X_train_norm, y_train))
# Out:
# MAE 2.369143566311579
# RMSE 4.000147182514744
# R2 score 0.693183720676529
